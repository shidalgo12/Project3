# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import os

# %%
# File to Load
file_to_load = "NBA_Shooting_Stats_1984-2019.csv"

# Read .csv File and store into Pandas data frame
nba_df = pd.read_csv(file_to_load)
nba_df
# Out:
#        SEASON    #               PLAYER  GP   MIN   PTS   FGM   FGA   FG%  \
# 0     1984-85    1         Bernard King  55  37.5  32.9  12.6  23.7  53.0
# 1     1984-85    2           Larry Bird  80  39.5  28.7  11.5  22.0  52.2
# 2     1984-85    3       Michael Jordan  82  38.3  28.2  10.2  19.8  51.5
# 3     1984-85    4         Purvis Short  78  39.5  28.0  10.5  22.8  46.0
# 4     1984-85    5         Alex English  81  36.1  27.9  11.6  22.4  51.8
# ...       ...  ...                  ...  ..   ...   ...   ...   ...   ...
# 7115  2019-20  259     Anthony Tolliver  47  15.6   3.5   1.1   3.3  34.8
# 7116  2019-20  260      Rodney McGruder  50  15.0   3.2   1.2   3.1  39.1
# 7117  2019-20  261         Semi Ojeleye  61  14.6   3.1   1.1   2.6  40.9
# 7118  2019-20  262  Matthew Dellavedova  57  14.4   3.1   1.1   3.1  35.4
# 7119  2019-20  263         Goga Bitadze  49   8.4   3.1   1.2   2.6  47.3
#
#       3PM  ...   FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 0     0.0  ...  10.0  77.2   2.1   3.7   5.8  3.7  1.3  0.3  3.7  26.8
# 1     0.7  ...   5.7  88.2   2.1   8.5  10.5  6.6  1.6  1.2  3.1  34.4
# 2     0.1  ...   9.1  84.5   2.0   4.5   6.5  5.9  2.4  0.8  3.5  29.2
# 3     0.6  ...   7.9  81.7   2.0   3.1   5.1  3.0  1.5  0.3  3.1  21.1
# 4     0.0  ...   5.7  82.9   2.5   3.1   5.7  4.2  1.2  0.6  3.1  24.8
# ...   ...  ...   ...   ...   ...   ...   ...  ...  ...  ...  ...   ...
# 7115  0.8  ...   0.5  72.0   0.6   2.2   2.8  0.7  0.3  0.2  0.6   4.7
# 7116  0.4  ...   0.6  53.6   0.5   2.0   2.6  0.6  0.5  0.2  0.4   4.4
# 7117  0.6  ...   0.5  89.3   0.4   1.6   2.0  0.5  0.3  0.1  0.2   4.3
# 7118  0.4  ...   0.6  86.5   0.3   1.0   1.3  3.2  0.4  0.0  1.0   4.9
# 7119  0.1  ...   0.7  72.7   0.4   1.5   2.0  0.4  0.1  0.7  0.5   4.2
#
# [7120 rows x 23 columns]

# %%
scoring_df = nba_df[['SEASON','PLAYER','GP','PTS']]
scoring_df
# Out:
#        SEASON               PLAYER  GP   PTS
# 0     1984-85         Bernard King  55  32.9
# 1     1984-85           Larry Bird  80  28.7
# 2     1984-85       Michael Jordan  82  28.2
# 3     1984-85         Purvis Short  78  28.0
# 4     1984-85         Alex English  81  27.9
# ...       ...                  ...  ..   ...
# 7115  2019-20     Anthony Tolliver  47   3.5
# 7116  2019-20      Rodney McGruder  50   3.2
# 7117  2019-20         Semi Ojeleye  61   3.1
# 7118  2019-20  Matthew Dellavedova  57   3.1
# 7119  2019-20         Goga Bitadze  49   3.1
#
# [7120 rows x 4 columns]
